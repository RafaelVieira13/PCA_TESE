# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
df = pd.read_csv('C:/Users/Administrador/OneDrive/Ambiente de Trabalho/Article_Organize_Data/PCA_Data.csv')
df
# Out:
#     No Amostra Data de colheita Zona de Produção           Espécie  \
# 0       618/20      11/ago/2020              EMN    Ostra-japonesa
# 1       647/20      19/ago/2020              EMR  Ostra-portuguesa
# 2        60/22       08/02/2022              EMR  Ostra-portuguesa
# 3       510/21       08/06/2021             RIAV       Amêijoa-boa
# 4        15227      06/Abr/2016              EMI  Amêijoa-japonesa
# ..         ...              ...              ...               ...
# 359    1005/22       21/09/2022             RIAV    Ostra-japonesa
# 360    1016/22       26/09/2022               L5          Mexilhão
# 361    1023/22       27/09/2022              EMR  Ostra-portuguesa
# 362    1038/22       28/09/2022              ELM    Ostra-japonesa
# 363    1039/22       28/09/2022              ELM  Ostra-portuguesa
#
#      Cd (mg/kg)  Hg (mg/kg)  Pb (mg/kg)  E.coli (NMP/100G)  Day Month  Year  \
# 0          0.14       0.019        0.08               17.0   11   Aug  2020
# 1          0.90       0.016        0.06               17.0   19   Aug  2020
# 2          1.20       0.030        0.01               45.0    8   Feb  2022
# 3          0.04       0.019        0.01              490.0    8   Jun  2021
# 4          0.18       0.024        0.20             1300.0    6   Apr  2016
# ..          ...         ...         ...                ...  ...   ...   ...
# 359        0.35       0.025        0.21               78.0   21  Sept  2022
# 360        0.20       0.011        0.15               40.0   26  Sept  2022
# 361        1.40       0.030        0.01              230.0   27  Sept  2022
# 362        0.20       0.030        0.10              490.0   28  Sept  2022
# 363        0.31       0.030        0.13              790.0   28  Sept  2022
#
#      Season Class
# 0       Dry     A
# 1       Dry     A
# 2    Rainny     A
# 3       Dry     B
# 4       Dry     B
# ..      ...   ...
# 359     Dry     A
# 360     Dry     A
# 361     Dry     A
# 362     Dry     B
# 363     Dry     B
#
# [364 rows x 13 columns]

# %% [markdown]
# # EDA
#
# Based on the 'Zona de produção' let´s crete a new column called 'Production Area' with the respective 'Production Area':

# %%
df['Zona de Produção'].value_counts()
# Out:
# ETJ     61
# ESD1    55
# EMR     45
# OLH     29
# ESD2    27
# RIAV    27
# ELM     18
# LOB     18
# EMN     12
# L5       9
# L4       8
# FAR      8
# FUZ      6
# LAG      6
# POR      5
# LAL      5
# TAV      5
# L1       4
# EMI      3
# VT       3
# L7c1     3
# L8       3
# L7a      2
# L7b      1
# L6       1
# Name: Zona de Produção, dtype: int64

# %%
def production_area(area):
    if area == 'ELM':
        return 'Norte'
    if area == 'L1':
        return 'Norte'
    elif area == 'EMI':
        return 'Centro'
    elif area == 'RIAV':
        return 'Centro'
    elif area=='L4':
        return 'Centro'
    elif area == 'EMN':
        return 'Centro'
    elif area == 'L5':
        return 'Lisboa e Vale do Tejo'
    elif area == 'ETJ':
        return 'Lisboa e Vale do Tejo'
    elif area == 'LOB':
        return 'Lisboa e Vale do Tejo'
    elif area == 'ESD1':
        return 'Alentejo'
    elif area == 'ESD2':
        return 'Alentejo'
    elif area == 'EMR':
        return 'Alentejo'
    elif area == 'L6':
        return 'Alentejo'
    elif area == 'OLH':
        return 'Algarve'
    elif area == 'FAR':
        return 'Algarve'
    elif area == 'FUZ':
        return 'Algarve'
    elif area == 'TAV':
        return 'Algarve'
    elif area == 'VT':
        return 'Algarve'
    elif area == 'L7c1':
        return 'Algarve'
    elif area == 'L7a':
        return 'Algarve'
    elif area == 'L7b':
        return 'Algarve'
    elif area == 'L8':
        return 'Algarve'
    elif area == 'POR':
        return 'Algarve'
    elif area == 'LAG':
        return 'Algarve'
    elif area == 'LAL':
        return 'Algarve'

# %%
df['Área de Produção'] = df['Zona de Produção'].apply(production_area)
df['Área de Produção'].value_counts()
# Out:
# Alentejo                 128
# Lisboa e Vale do Tejo     88
# Algarve                   76
# Centro                    50
# Norte                     22
# Name: Área de Produção, dtype: int64

# %%
df['Zona de Produção'].count()
# Out:
# 364

# %%
df['Área de Produção'].count()
# Out:
# 364

# %%
df
# Out:
#     No Amostra Data de colheita Zona de Produção           Espécie  \
# 0       618/20      11/ago/2020              EMN    Ostra-japonesa
# 1       647/20      19/ago/2020              EMR  Ostra-portuguesa
# 2        60/22       08/02/2022              EMR  Ostra-portuguesa
# 3       510/21       08/06/2021             RIAV       Amêijoa-boa
# 4        15227      06/Abr/2016              EMI  Amêijoa-japonesa
# ..         ...              ...              ...               ...
# 359    1005/22       21/09/2022             RIAV    Ostra-japonesa
# 360    1016/22       26/09/2022               L5          Mexilhão
# 361    1023/22       27/09/2022              EMR  Ostra-portuguesa
# 362    1038/22       28/09/2022              ELM    Ostra-japonesa
# 363    1039/22       28/09/2022              ELM  Ostra-portuguesa
#
#      Cd (mg/kg)  Hg (mg/kg)  Pb (mg/kg)  E.coli (NMP/100G)  Day Month  Year  \
# 0          0.14       0.019        0.08               17.0   11   Aug  2020
# 1          0.90       0.016        0.06               17.0   19   Aug  2020
# 2          1.20       0.030        0.01               45.0    8   Feb  2022
# 3          0.04       0.019        0.01              490.0    8   Jun  2021
# 4          0.18       0.024        0.20             1300.0    6   Apr  2016
# ..          ...         ...         ...                ...  ...   ...   ...
# 359        0.35       0.025        0.21               78.0   21  Sept  2022
# 360        0.20       0.011        0.15               40.0   26  Sept  2022
# 361        1.40       0.030        0.01              230.0   27  Sept  2022
# 362        0.20       0.030        0.10              490.0   28  Sept  2022
# 363        0.31       0.030        0.13              790.0   28  Sept  2022
#
#      Season Class       Área de Produção
# 0       Dry     A                 Centro
# 1       Dry     A               Alentejo
# 2    Rainny     A               Alentejo
# 3       Dry     B                 Centro
# 4       Dry     B                 Centro
# ..      ...   ...                    ...
# 359     Dry     A                 Centro
# 360     Dry     A  Lisboa e Vale do Tejo
# 361     Dry     A               Alentejo
# 362     Dry     B                  Norte
# 363     Dry     B                  Norte
#
# [364 rows x 14 columns]

# %% [markdown]
# # PCA Analyse

# %% [markdown]
# Let´s only use numerical data in order to perform the pca

# %%
df_pca = df[['Cd (mg/kg)','Hg (mg/kg)','Pb (mg/kg)','E.coli (NMP/100G)']]
df_pca
# Out:
#      Cd (mg/kg)  Hg (mg/kg)  Pb (mg/kg)  E.coli (NMP/100G)
# 0          0.14       0.019        0.08               17.0
# 1          0.90       0.016        0.06               17.0
# 2          1.20       0.030        0.01               45.0
# 3          0.04       0.019        0.01              490.0
# 4          0.18       0.024        0.20             1300.0
# ..          ...         ...         ...                ...
# 359        0.35       0.025        0.21               78.0
# 360        0.20       0.011        0.15               40.0
# 361        1.40       0.030        0.01              230.0
# 362        0.20       0.030        0.10              490.0
# 363        0.31       0.030        0.13              790.0
#
# [364 rows x 4 columns]

# %% [markdown]
# ## 1. Data Preprocessing

# %% [markdown]
# __Feature Scaling__

# %%
sc = StandardScaler()
df_pca = sc.fit_transform(df_pca)
df_pca
# Out:
# array([[-0.48694885, -0.53931858, -0.45701545, -0.2620864 ],
#        [ 1.41248193, -0.69948608, -0.49057817, -0.2620864 ],
#        [ 2.16225724,  0.04796225, -0.57448497, -0.25656339],
#        ...,
#        [ 2.66210745,  0.04796225, -0.57448497, -0.22007211],
#        [-0.33699379,  0.04796225, -0.42345273, -0.16878707],
#        [-0.06207618,  0.04796225, -0.37310865, -0.10961202]])

# %% [markdown]
# ## 2. Aplly PCA

# %%
pca = PCA()
pca_results = pca.fit_transform(df_pca)
pca_results
# Out:
# array([[-0.50476489,  0.06742207, -0.73797482, -0.03994935],
#        [-1.34303343, -0.2873102 ,  0.92796426, -0.21526399],
#        [-1.20782665, -0.62208491,  1.76650317,  0.32733198],
#        ...,
#        [-1.38900195, -0.69374855,  2.2277905 ,  0.30645912],
#        [-0.15107704, -0.03494189, -0.42783398,  0.34143719],
#        [-0.21036586, -0.04550541, -0.15221538,  0.29645342]])

# %%
# Crete a dataframe with pca_results
pca_results = pd.DataFrame(pca_results,columns=['PC1','PC2','PC3','PC4'])
pca_results
# Out:
#           PC1       PC2       PC3       PC4
# 0   -0.504765  0.067422 -0.737975 -0.039949
# 1   -1.343033 -0.287310  0.927964 -0.215264
# 2   -1.207827 -0.622085  1.766503  0.327332
# 3   -0.468826  0.224603 -0.958253  0.062258
# 4   -0.193899  0.182327 -0.467308  0.012493
# ..        ...       ...       ...       ...
# 359 -0.356352 -0.148071 -0.141621  0.001398
# 360 -0.753193  0.133269 -0.679953 -0.426360
# 361 -1.389002 -0.693749  2.227790  0.306459
# 362 -0.151077 -0.034942 -0.427834  0.341437
# 363 -0.210366 -0.045505 -0.152215  0.296453
#
# [364 rows x 4 columns]

# %%
# Variance Explained By Each PCA
explained_variance = pca.explained_variance_
explained_variance
# Out:
# array([1.78078583, 0.98605673, 0.86928207, 0.37489466])

# %% [markdown]
# ## 3.Get a DataFrame With The Orignal Data and PC's

# %%
df.reset_index(inplace=True)
df.drop(columns='index')
df.reset_index(inplace=True)

pca_results.reset_index(inplace=True)
pca_results

df_pca1 = pd.merge(df,pca_results, on='index', how='left')
df_pca1.drop(columns=['index'],inplace=True)
df_pca1
# Out:
#     No Amostra Data de colheita Zona de Produção           Espécie  \
# 0       618/20      11/ago/2020              EMN    Ostra-japonesa
# 1       647/20      19/ago/2020              EMR  Ostra-portuguesa
# 2        60/22       08/02/2022              EMR  Ostra-portuguesa
# 3       510/21       08/06/2021             RIAV       Amêijoa-boa
# 4        15227      06/Abr/2016              EMI  Amêijoa-japonesa
# ..         ...              ...              ...               ...
# 359    1005/22       21/09/2022             RIAV    Ostra-japonesa
# 360    1016/22       26/09/2022               L5          Mexilhão
# 361    1023/22       27/09/2022              EMR  Ostra-portuguesa
# 362    1038/22       28/09/2022              ELM    Ostra-japonesa
# 363    1039/22       28/09/2022              ELM  Ostra-portuguesa
#
#      Cd (mg/kg)  Hg (mg/kg)  Pb (mg/kg)  E.coli (NMP/100G)  Day Month  Year  \
# 0          0.14       0.019        0.08               17.0   11   Aug  2020
# 1          0.90       0.016        0.06               17.0   19   Aug  2020
# 2          1.20       0.030        0.01               45.0    8   Feb  2022
# 3          0.04       0.019        0.01              490.0    8   Jun  2021
# 4          0.18       0.024        0.20             1300.0    6   Apr  2016
# ..          ...         ...         ...                ...  ...   ...   ...
# 359        0.35       0.025        0.21               78.0   21  Sept  2022
# 360        0.20       0.011        0.15               40.0   26  Sept  2022
# 361        1.40       0.030        0.01              230.0   27  Sept  2022
# 362        0.20       0.030        0.10              490.0   28  Sept  2022
# 363        0.31       0.030        0.13              790.0   28  Sept  2022
#
#      Season Class       Área de Produção       PC1       PC2       PC3  \
# 0       Dry     A                 Centro -0.504765  0.067422 -0.737975
# 1       Dry     A               Alentejo -1.343033 -0.287310  0.927964
# 2    Rainny     A               Alentejo -1.207827 -0.622085  1.766503
# 3       Dry     B                 Centro -0.468826  0.224603 -0.958253
# 4       Dry     B                 Centro -0.193899  0.182327 -0.467308
# ..      ...   ...                    ...       ...       ...       ...
# 359     Dry     A                 Centro -0.356352 -0.148071 -0.141621
# 360     Dry     A  Lisboa e Vale do Tejo -0.753193  0.133269 -0.679953
# 361     Dry     A               Alentejo -1.389002 -0.693749  2.227790
# 362     Dry     B                  Norte -0.151077 -0.034942 -0.427834
# 363     Dry     B                  Norte -0.210366 -0.045505 -0.152215
#
#           PC4
# 0   -0.039949
# 1   -0.215264
# 2    0.327332
# 3    0.062258
# 4    0.012493
# ..        ...
# 359  0.001398
# 360 -0.426360
# 361  0.306459
# 362  0.341437
# 363  0.296453
#
# [364 rows x 18 columns]

# %% [markdown]
# ## 4. Correlation Between Variabels

# %%
corr = df_pca1.corr()
plt.figure(figsize=(10,8))
sns.heatmap(corr,annot = True, fmt = '.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 4. PC1 VS PC2

# %% [markdown]
# __By Specie__

# %%
sns.scatterplot(data=df_pca1, x="PC1", y="PC2", hue='Espécie', marker='o',s=80,edgecolor='k',legend='full')
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.title('PC1 vs PC2 by Specie')
plt.legend(fontsize=8, loc='best')
plt.show()

# %% [markdown]
# __Production Area__

# %%
sns.scatterplot(data=df_pca1, x='PC1', y='PC2', hue='Área de Produção',
                marker='o', s=50, edgecolor='k', legend='full')
plt.legend(fontsize=7)
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('PCA1 vs PCA2 by Production Area')
plt.show()

# %% [markdown]
# __Season__

# %%
sns.scatterplot(data = df_pca1, x= 'PC1',y = 'PC2', hue='Season', marker='o', s=80,edgecolor='k')
plt.legend(fontsize=7)
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('PC1 vs PC2 by Season')
plt.show()
